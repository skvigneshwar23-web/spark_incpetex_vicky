# %%
dbutils.widgets.text("dbname","test")
dbutils.widgets.text("cur_user","test")
dbutils.widgets.text("range_num","1")

# %%
def create_df(lst,cols):
    return spark.createDataFrame(lst,cols)

# %%
def get_msg():
    print("runnig from dbutils notebook")

# %%
db_name=dbutils.widgets.get("dbname")
user_name=dbutils.widgets.get("cur_user")
range_num=dbutils.widgets.get("range_num")

print(db_name, user_name,range_num)

# %%
df=create_df(list(range(int(range_num))),["my_id"])

df.show()

# df:datafrme myid

# %%
dbutils.notebook.exit({"status":"success","rec_count":"50"})
