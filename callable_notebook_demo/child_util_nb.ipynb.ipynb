# %%
print("load started ")
print("i am from child_util_nb ")

# %%
def get_seq_number(num):
    lst_num=list(range(num))
    return lst_num

# %%
def print_line(length):
    print('*'*length)

# %%
print("load completed , now we can acees all util fucntions in the main NB ")
