# %% [markdown]
# Call child Notebook in the impl /main Notebook
#
# How to call child / other noteboook from main notebook
#
# 1.%run
#
# we will use load all functions / var in the main notebook itself , for accessing
# -- we are runnning notebook locally / inline -- we cant pass parameter
#
# 2.dbutils.notebook.run()
#
# -- this will invoke notebook as seperate instance / seperate job
#
# -- pass arguments , capture the return value in string format

# %%
# %run ./child_util_nb.ipynb

# %%
print(get_seq_number(10))

# %%
print_line(1000)

# %%
# dbutils.help()
# path , timeout in sec , parameter
dbutils.notebook.run("./child_util_nb.ipynb",100)

# %%
# %run ./child_dbutil_nb.ipynb

# %%
get_msg()

# %%
db_name="wd37"

user_name="izuser_wd37"
range_num="3"



# pass parameter to the NB

ret_value=dbutils.notebook.run("./child_dbutil_nb.ipynb",100,arguments="dbname")

print(ret_value)

print(type(ret_value))

# %%
import myutil_test as t  # Ensure 'myutil_test' is installed or replace with a valid module

print(t.get_msg())
