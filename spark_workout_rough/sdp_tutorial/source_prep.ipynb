# %%
# %sql
create table sdp_catalog.source.sales (
   order_id int,
   product_id int ,
   revenue float,
   date date,
   store_id int 
);

insert into sdp_catalog.source.sales values
 (9, 100, 1000, '2022-01-01', 1),
 (10, 100, 1000, '2022-01-02', 1),
 (3, 100, 1000, '2022-01-03', 1),
 (4, 100, 1000, '2022-01-04', 1)
;

# %%
# %sql
select * from sdp_catalog.source.sales

# %%
# %sql
drop table sdp_catalog.source.src_sales_stream

# %%
# %sql
create table sdp_catalog.source.sales_north (
   order_id int,
   product_id int ,
   revenue float,
   date date,
   store_id int 
);

insert into sdp_catalog.source.sales_north values
 (1, 100, 1000, '2022-01-01', 1),
 (2, 100, 1000, '2022-01-02', 1),
 (3, 100, 1000, '2022-01-03', 1),
 (4, 100, 1000, '2022-01-04', 1)
;

create table sdp_catalog.source.sales_south (
   order_id int,
   product_id int ,
   revenue float,
   date date,
   store_id int 
);

insert into sdp_catalog.source.sales_south values
 (5, 100, 1000, '2022-01-01', 1),
 (6, 100, 1000, '2022-01-02', 1),
 (7, 100, 1000, '2022-01-03', 1),
 (8, 100, 1000, '2022-01-04', 1)
;

# %%
# %sql
select * from sdp_catalog.source.total_sales

# %%
# %sql
create table sdp_catalog.source.products
(
    product_id int,
    product_name string,
    category string,
    subcategory string,
    updated_at timestamp
)

# %%
# %sql
insert into sdp_catalog.source.products values
 --(100, 'product1', 'category1', 'subcategory1', current_timestamp()),
 --(101, 'product2', 'category2', 'subcategory2', current_timestamp()),
 (106, 'product5', 'category5', 'subcategory9', null),
 (null, 'product4', 'category4', 'subcategory6', current_timestamp());

# %%
# %sql
select * from sdp_catalog.source.products ;

# %%
# %sql
select * from sdp_catalog.source.products_scd2 ;

# %%
# %sql
select * from sdp_catalog.source.products_scd1 ;

# %%
# %sql
select * from sdp_catalog.source.products_table ;
